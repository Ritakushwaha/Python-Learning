# %% [markdown]
# # Pandas Series
# one-dimensional labelled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called indexes. Pandas Series is nothing but a column in an excel sheet. Labels need not be unique but must be a hashable type. The object supports both integer and label-based indexing and provides a host of methods for performing operations involving the index.

# %% [markdown]
# ## Creating a Series

# %%
import pandas as pd
import numpy as np


# Creating empty series
ser = pd.Series()
print(ser)

# simple array
data = np.array(['rita', 'girwar', 'priyanshi', 'pragya', 'vijaya'])

ser = pd.Series(data)
print(ser)
# Out:
# Series([], dtype: float64)
# 0         rita
# 1       girwar
# 2    priyanshi
# 3       pragya
# 4       vijaya
# dtype: object

# %% [markdown]
# # Pandas DataFrame
# two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns

# %% [markdown]
# ## Creating a DataFrame

# %%
import pandas as pd

# Calling DataFrame constructor
df = pd.DataFrame()
print(df)

# list of strings
lst = ['rita', 'girwar', 'priyanshi', 'pragya', 'vijaya']

# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#            0
# 0       rita
# 1     girwar
# 2  priyanshi
# 3     pragya
# 4     vijaya

# %% [markdown]
# ### Creating DataFrame from dict of ndarray/lists

# %%
import pandas as pd

# intialise data of lists.
data = {'Name':['rita', 'girwar', 'priyanshi', 'pragya', 'vijaya'],
        'Age':[24, 24, 23, 24,25]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
df
# Out:
#         Name  Age
# 0       rita   24
# 1     girwar   24
# 2  priyanshi   23
# 3     pragya   24
# 4     vijaya   25

# %% [markdown]
# ### Column Selection

# %%
import pandas as pd
 
# Define a dictionary containing employee data
data = {'Name':['rita', 'girwar', 'priyanshi', 'pragya', 'vijaya'],
        'Age':[24, 24, 23, 24,25],
        'Address':['Bhopal', 'Jodhpur', 'Bareili', 'Vidisha','Kolkata']}
 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data)
 
# select two columns
df[['Name', 'Address']]
# Out:
#         Name  Address
# 0       rita   Bhopal
# 1     girwar  Jodhpur
# 2  priyanshi  Bareili
# 3     pragya  Vidisha
# 4     vijaya  Kolkata

# %% [markdown]
# ### Row Selection

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
df = pd.read_csv("Automobile_data.csv", index_col='company')
df
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111               21  13495.0
# alfa-romero         111               21  16500.0
# alfa-romero         154               19  16500.0
# audi                102               24  13950.0
# audi                115               18  17450.0
# ...                 ...              ...      ...
# volkswagen           85               27   7975.0
# volkswagen           52               37   7995.0
# volkswagen          100               26   9995.0
# volvo               114               23  12940.0
# volvo               114               23  13415.0
#
# [61 rows x 8 columns]

# %%
# retrieving row by loc method
print('Rows having company name : volvo ')
first = df.loc['volvo']
first
# Out:
# Rows having company name : volvo
#         body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# volvo        sedan       104.3   188.8         ohc             four
# volvo        wagon       104.3   188.8         ohc             four
#
#          horsepower  average-mileage    price
# company
# volvo           114               23  12940.0
# volvo           114               23  13415.0

# %%
print('Rows having company name : audi ')
second = df.loc['audi']
second
# Out:
# Rows having company name : audi
#         body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# audi         sedan        99.8   176.6         ohc             four
# audi         sedan        99.4   176.6         ohc             five
# audi         sedan        99.8   177.3         ohc             five
# audi         wagon       105.8   192.7         ohc             five
#
#          horsepower  average-mileage    price
# company
# audi            102               24  13950.0
# audi            115               18  17450.0
# audi            110               19  15250.0
# audi            110               19  18920.0

# %% [markdown]
# ### Indexing/Subset Selection and Selecting Data

# %% [markdown]
# Using df[]

# %%
import pandas as pd
 
# making data frame from csv file
df = pd.read_csv("Automobile_data.csv")

# retrieving columns by indexing operator
comp_col = df['company']
comp_col
# Out:
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
#          ...
# 56     volkswagen
# 57     volkswagen
# 58     volkswagen
# 59          volvo
# 60          volvo
# Name: company, Length: 61, dtype: object

# %% [markdown]
# Using df.loc[]

# %%
import pandas as pd
 
# making data frame from csv file
df = pd.read_csv("Automobile_data.csv",index_col='company')

# retrieving row by loc method
print('Rows having company name : volvo ')
first = df.loc['volvo']
first
# Out:
# Rows having company name : volvo
#         body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# volvo        sedan       104.3   188.8         ohc             four
# volvo        wagon       104.3   188.8         ohc             four
#
#          horsepower  average-mileage    price
# company
# volvo           114               23  12940.0
# volvo           114               23  13415.0

# %% [markdown]
# Using df.iloc[<position>]

# %%
import pandas as pd
 
# making data frame from csv file
df = pd.read_csv("Automobile_data.csv",index_col='company')

# retrieving rows by iloc method 
first = df.iloc[0,7] #value at 1 row and 9 column
first
# Out:
# 13495.0

# %% [markdown]
# ### Accessing dataframe with a boolean index

# %%
# importing pandas as pd
import pandas as pd

# dictionary of lists
data = {'Name':['rita', 'girwar', 'priyanshi', 'pragya', 'vijaya'],
        'Age':[24, 24, 23, 24,25],
        'Address':['Bhopal', 'Jodhpur', 'Bareili', 'Vidisha','Kolkata']}

df = pd.DataFrame(data, index = [True, False, True, False,True])

print(df)
# Out:
#             Name  Age  Address
# True        rita   24   Bhopal
# False     girwar   24  Jodhpur
# True   priyanshi   23  Bareili
# False     pragya   24  Vidisha
# True      vijaya   25  Kolkata

# %% [markdown]
# #### Accessing a Dataframe with a boolean index using .loc[]

# %%
df_true = df.loc[True]
df_true
# Out:
#            Name  Age  Address
# True       rita   24   Bhopal
# True  priyanshi   23  Bareili
# True     vijaya   25  Kolkata

# %% [markdown]
# #### Accessing a Dataframe with a boolean index using .iloc[]

# %%
df_false = df.iloc[1]
df_false
# Out:
# Name        girwar
# Age             24
# Address    Jodhpur
# dtype: object

# %% [markdown]
# #### Accessing a Dataframe with a boolean index using .ix[] (deprecated)

# %%
df_= df.ix[True]
df_
# Out:
# C:\Users\rikushwa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#            Name  Age  Address
# True       rita   24   Bhopal
# True  priyanshi   23  Bareili
# True     vijaya   25  Kolkata

# %%
df__ = df.ix[1]
df__
# Out:
# C:\Users\rikushwa\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Name        girwar
# Age             24
# Address    Jodhpur
# dtype: object

# %% [markdown]
# #### Applying a boolean mask to a dataframe

# %%
df = pd.DataFrame(data, index = [0, 1, 2, 3, 4])
df___ = df[[True, True, True, False, False]]
df___
# Out:
#         Name  Age  Address
# 0       rita   24   Bhopal
# 1     girwar   24  Jodhpur
# 2  priyanshi   23  Bareili

# %% [markdown]
# #### Masking data based on column value

# %%
df_age = df['Age'] == 24
df_age
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Age, dtype: bool

# %%
df_age = df['Age'] > 24
df_age
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Age, dtype: bool

# %%
df1 = df.index > 2
df[df1]
# Out:
#      Name  Age  Address
# 3  pragya   24  Vidisha
# 4  vijaya   25  Kolkata

# %% [markdown]
# ## Working with Missing Data

# %% [markdown]
# ### Checking for missing values using isnull() and notnull()

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
df = pd.read_csv("Automobile_data.csv", index_col='company')
df.isnull()
# Out:
#              body-style  wheel-base  length  engine-type  num-of-cylinders  \
# company
# alfa-romero       False       False   False        False             False
# alfa-romero       False       False   False        False             False
# alfa-romero       False       False   False        False             False
# audi              False       False   False        False             False
# audi              False       False   False        False             False
# ...                 ...         ...     ...          ...               ...
# volkswagen        False       False   False        False             False
# volkswagen        False       False   False        False             False
# volkswagen        False       False   False        False             False
# volvo             False       False   False        False             False
# volvo             False       False   False        False             False
#
#              horsepower  average-mileage  price
# company
# alfa-romero       False            False  False
# alfa-romero       False             True  False
# alfa-romero       False            False  False
# audi              False            False  False
# audi              False            False  False
# ...                 ...              ...    ...
# volkswagen        False            False  False
# volkswagen        False            False  False
# volkswagen        False            False  False
# volvo             False            False  False
# volvo             False            False  False
#
# [61 rows x 8 columns]

# %%
df_null= pd.isnull(df['average-mileage'])
df_null
# Out:
# company
# alfa-romero    False
# alfa-romero     True
# alfa-romero    False
# audi           False
# audi           False
#                ...
# volkswagen     False
# volkswagen     False
# volkswagen     False
# volvo          False
# volvo          False
# Name: average-mileage, Length: 61, dtype: bool

# %%
df.notnull()
# Out:
#              body-style  wheel-base  length  engine-type  num-of-cylinders  \
# company
# alfa-romero        True        True    True         True              True
# alfa-romero        True        True    True         True              True
# alfa-romero        True        True    True         True              True
# audi               True        True    True         True              True
# audi               True        True    True         True              True
# ...                 ...         ...     ...          ...               ...
# volkswagen         True        True    True         True              True
# volkswagen         True        True    True         True              True
# volkswagen         True        True    True         True              True
# volvo              True        True    True         True              True
# volvo              True        True    True         True              True
#
#              horsepower  average-mileage  price
# company
# alfa-romero        True             True   True
# alfa-romero        True            False   True
# alfa-romero        True             True   True
# audi               True             True   True
# audi               True             True   True
# ...                 ...              ...    ...
# volkswagen         True             True   True
# volkswagen         True             True   True
# volkswagen         True             True   True
# volvo              True             True   True
# volvo              True             True   True
#
# [61 rows x 8 columns]

# %%
df_not_null= pd.notnull(df['average-mileage'])
df_not_null
# Out:
# company
# alfa-romero     True
# alfa-romero    False
# alfa-romero     True
# audi            True
# audi            True
#                ...
# volkswagen      True
# volkswagen      True
# volkswagen      True
# volvo           True
# volvo           True
# Name: average-mileage, Length: 61, dtype: bool

# %% [markdown]
# ### Filling missing values using fillna(), replace() and interpolate()

# %%
df1 = df.fillna(0) #fill with particular value
df1
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111              0.0  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0
# ...                 ...              ...      ...
# volkswagen           85             27.0   7975.0
# volkswagen           52             37.0   7995.0
# volkswagen          100             26.0   9995.0
# volvo               114             23.0  12940.0
# volvo               114             23.0  13415.0
#
# [61 rows x 8 columns]

# %%
df_fill_previous_value=df.fillna(method ='pad') # fill null values with previous value
df_fill_previous_value
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111             21.0  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0
# ...                 ...              ...      ...
# volkswagen           85             27.0   7975.0
# volkswagen           52             37.0   7995.0
# volkswagen          100             26.0   9995.0
# volvo               114             23.0  12940.0
# volvo               114             23.0  13415.0
#
# [61 rows x 8 columns]

# %%
df_fill_previous_value=df.fillna(method ='bfill') # fill null values with next value
df_fill_previous_value
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111             19.0  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0
# ...                 ...              ...      ...
# volkswagen           85             27.0   7975.0
# volkswagen           52             37.0   7995.0
# volkswagen          100             26.0   9995.0
# volvo               114             23.0  12940.0
# volvo               114             23.0  13415.0
#
# [61 rows x 8 columns]

# %%
df['average-mileage'].fillna('No Average Mileage', inplace = True )
df
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower     average-mileage    price
# company
# alfa-romero         111                  21  13495.0
# alfa-romero         111  No Average Mileage  16500.0
# alfa-romero         154                  19  16500.0
# audi                102                  24  13950.0
# audi                115                  18  17450.0
# ...                 ...                 ...      ...
# volkswagen           85                  27   7975.0
# volkswagen           52                  37   7995.0
# volkswagen          100                  26   9995.0
# volvo               114                  23  12940.0
# volvo               114                  23  13415.0
#
# [61 rows x 8 columns]

# %%
df = df.replace('No Average Mileage',np.nan) # replace No Average Mileage with null field
df
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111              NaN  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0
# ...                 ...              ...      ...
# volkswagen           85             27.0   7975.0
# volkswagen           52             37.0   7995.0
# volkswagen          100             26.0   9995.0
# volvo               114             23.0  12940.0
# volvo               114             23.0  13415.0
#
# [61 rows x 8 columns]

# %%
df.head()
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111              NaN  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0

# %%
df3 = df.interpolate(method ='linear', limit_direction ='forward')
df3
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111             20.0  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0
# ...                 ...              ...      ...
# volkswagen           85             27.0   7975.0
# volkswagen           52             37.0   7995.0
# volkswagen          100             26.0   9995.0
# volvo               114             23.0  12940.0
# volvo               114             23.0  13415.0
#
# [61 rows x 8 columns]

# %%
df.head()
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
#
#              horsepower     average-mileage    price
# company
# alfa-romero         111                  21  13495.0
# alfa-romero         111  No Average Mileage  16500.0
# alfa-romero         154                  19  16500.0
# audi                102                  24  13950.0
# audi                115                  18  17450.0

# %%
df4 = df.interpolate(method ='linear', limit_direction ='backward', limit = 1)
df4
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111             20.0  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0
# ...                 ...              ...      ...
# volkswagen           85             27.0   7975.0
# volkswagen           52             37.0   7995.0
# volkswagen          100             26.0   9995.0
# volvo               114             23.0  12940.0
# volvo               114             23.0  13415.0
#
# [61 rows x 8 columns]

# %% [markdown]
# #### Dropping missing values using dropna()

# %%
df.head()
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111              NaN  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0

# %%
df5 = df.dropna()
df5
# Out:
#                 body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero    convertible        88.6   168.8        dohc             four
# alfa-romero      hatchback        94.5   171.2        ohcv              six
# audi                 sedan        99.8   176.6         ohc             four
# audi                 sedan        99.4   176.6         ohc             five
# audi                 sedan        99.8   177.3         ohc             five
# audi                 wagon       105.8   192.7         ohc             five
# bmw                  sedan       101.2   176.8         ohc             four
# bmw                  sedan       101.2   176.8         ohc             four
# bmw                  sedan       101.2   176.8         ohc              six
# bmw                  sedan       103.5   189.0         ohc              six
# bmw                  sedan       103.5   193.8         ohc              six
# bmw                  sedan       110.0   197.0         ohc              six
# chevrolet        hatchback        88.4   141.1           l            three
# chevrolet        hatchback        94.5   155.9         ohc             four
# chevrolet            sedan        94.5   158.8         ohc             four
# dodge            hatchback        93.7   157.3         ohc             four
# dodge            hatchback        93.7   157.3         ohc             four
# honda                wagon        96.5   157.1         ohc             four
# honda                sedan        96.5   175.4         ohc             four
# honda                sedan        96.5   169.1         ohc             four
# isuzu                sedan        94.3   170.7         ohc             four
# jaguar               sedan       113.0   199.6        dohc              six
# jaguar               sedan       113.0   199.6        dohc              six
# jaguar               sedan       102.0   191.7        ohcv           twelve
# mazda            hatchback        93.1   159.1         ohc             four
# mazda            hatchback        93.1   159.1         ohc             four
# mazda            hatchback        93.1   159.1         ohc             four
# mazda            hatchback        95.3   169.0       rotor              two
# mazda                sedan       104.9   175.0         ohc             four
# mercedes-benz        sedan       110.0   190.9         ohc             five
# mercedes-benz        wagon       110.0   190.9         ohc             five
# mercedes-benz        sedan       120.9   208.1        ohcv            eight
# mercedes-benz      hardtop       112.0   199.2        ohcv            eight
# mitsubishi       hatchback        93.7   157.3         ohc             four
# mitsubishi       hatchback        93.7   157.3         ohc             four
# mitsubishi           sedan        96.3   172.4         ohc             four
# mitsubishi           sedan        96.3   172.4         ohc             four
# nissan               sedan        94.5   165.3         ohc             four
# nissan               sedan        94.5   165.3         ohc             four
# nissan               sedan        94.5   165.3         ohc             four
# nissan               wagon        94.5   170.2         ohc             four
# nissan               sedan       100.4   184.6        ohcv              six
# porsche            hardtop        89.5   168.9        ohcf              six
# porsche        convertible        89.5   168.9        ohcf              six
# toyota           hatchback        95.7   158.7         ohc             four
# toyota           hatchback        95.7   158.7         ohc             four
# toyota           hatchback        95.7   158.7         ohc             four
# toyota               wagon        95.7   169.7         ohc             four
# toyota               wagon        95.7   169.7         ohc             four
# toyota               wagon        95.7   169.7         ohc             four
# toyota               wagon       104.5   187.8        dohc              six
# volkswagen           sedan        97.3   171.7         ohc             four
# volkswagen           sedan        97.3   171.7         ohc             four
# volkswagen           sedan        97.3   171.7         ohc             four
# volkswagen           sedan        97.3   171.7         ohc             four
# volvo                sedan       104.3   188.8         ohc             four
# volvo                wagon       104.3   188.8         ohc             four
#
#                horsepower  average-mileage    price
# company
# alfa-romero           111             21.0  13495.0
# alfa-romero           154             19.0  16500.0
# audi                  102             24.0  13950.0
# audi                  115             18.0  17450.0
# audi                  110             19.0  15250.0
# audi                  110             19.0  18920.0
# bmw                   101             23.0  16430.0
# bmw                   101             23.0  16925.0
# bmw                   121             21.0  20970.0
# bmw                   182             16.0  30760.0
# bmw                   182             16.0  41315.0
# bmw                   182             15.0  36880.0
# chevrolet              48             47.0   5151.0
# chevrolet              70             38.0   6295.0
# chevrolet              70             38.0   6575.0
# dodge                  68             31.0   6377.0
# dodge                  68             31.0   6229.0
# honda                  76             30.0   7295.0
# honda                 101             24.0  12945.0
# honda                 100             25.0  10345.0
# isuzu                  78             24.0   6785.0
# jaguar                176             15.0  32250.0
# jaguar                176             15.0  35550.0
# jaguar                262             13.0  36000.0
# mazda                  68             30.0   5195.0
# mazda                  68             31.0   6095.0
# mazda                  68             31.0   6795.0
# mazda                 101             17.0  11845.0
# mazda                  72             31.0  18344.0
# mercedes-benz         123             22.0  25552.0
# mercedes-benz         123             22.0  28248.0
# mercedes-benz         184             14.0  40960.0
# mercedes-benz         184             14.0  45400.0
# mitsubishi             68             37.0   5389.0
# mitsubishi             68             31.0   6189.0
# mitsubishi             88             25.0   6989.0
# mitsubishi             88             25.0   8189.0
# nissan                 55             45.0   7099.0
# nissan                 69             31.0   6649.0
# nissan                 69             31.0   6849.0
# nissan                 69             31.0   7349.0
# nissan                152             19.0  13499.0
# porsche               207             17.0  34028.0
# porsche               207             17.0  37028.0
# toyota                 62             35.0   5348.0
# toyota                 62             31.0   6338.0
# toyota                 62             31.0   6488.0
# toyota                 62             31.0   6918.0
# toyota                 62             27.0   7898.0
# toyota                 62             27.0   8778.0
# toyota                156             19.0  15750.0
# volkswagen             52             37.0   7775.0
# volkswagen             85             27.0   7975.0
# volkswagen             52             37.0   7995.0
# volkswagen            100             26.0   9995.0
# volvo                 114             23.0  12940.0
# volvo                 114             23.0  13415.0

# %%
df6 = df.dropna(how = 'all')# drop if all values is null
df6
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# alfa-romero         111             21.0  13495.0
# alfa-romero         111              NaN  16500.0
# alfa-romero         154             19.0  16500.0
# audi                102             24.0  13950.0
# audi                115             18.0  17450.0
# ...                 ...              ...      ...
# volkswagen           85             27.0   7975.0
# volkswagen           52             37.0   7995.0
# volkswagen          100             26.0   9995.0
# volvo               114             23.0  12940.0
# volvo               114             23.0  13415.0
#
# [61 rows x 8 columns]

# %%
df7 = df.dropna(axis = 1) # drop column with atleast 1 null values
df7 # price, average-mileage column has been dropped
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower
# company
# alfa-romero         111
# alfa-romero         111
# alfa-romero         154
# audi                102
# audi                115
# ...                 ...
# volkswagen           85
# volkswagen           52
# volkswagen          100
# volvo               114
# volvo               114
#
# [61 rows x 6 columns]

# %%
df8 = df.dropna(axis = 0,how ='any') # drop row with atleast 1 null values
df8 # price, average-mileage column has been dropped
# Out:
#                 body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero    convertible        88.6   168.8        dohc             four
# alfa-romero      hatchback        94.5   171.2        ohcv              six
# audi                 sedan        99.8   176.6         ohc             four
# audi                 sedan        99.4   176.6         ohc             five
# audi                 sedan        99.8   177.3         ohc             five
# audi                 wagon       105.8   192.7         ohc             five
# bmw                  sedan       101.2   176.8         ohc             four
# bmw                  sedan       101.2   176.8         ohc             four
# bmw                  sedan       101.2   176.8         ohc              six
# bmw                  sedan       103.5   189.0         ohc              six
# bmw                  sedan       103.5   193.8         ohc              six
# bmw                  sedan       110.0   197.0         ohc              six
# chevrolet        hatchback        88.4   141.1           l            three
# chevrolet        hatchback        94.5   155.9         ohc             four
# chevrolet            sedan        94.5   158.8         ohc             four
# dodge            hatchback        93.7   157.3         ohc             four
# dodge            hatchback        93.7   157.3         ohc             four
# honda                wagon        96.5   157.1         ohc             four
# honda                sedan        96.5   175.4         ohc             four
# honda                sedan        96.5   169.1         ohc             four
# isuzu                sedan        94.3   170.7         ohc             four
# jaguar               sedan       113.0   199.6        dohc              six
# jaguar               sedan       113.0   199.6        dohc              six
# jaguar               sedan       102.0   191.7        ohcv           twelve
# mazda            hatchback        93.1   159.1         ohc             four
# mazda            hatchback        93.1   159.1         ohc             four
# mazda            hatchback        93.1   159.1         ohc             four
# mazda            hatchback        95.3   169.0       rotor              two
# mazda                sedan       104.9   175.0         ohc             four
# mercedes-benz        sedan       110.0   190.9         ohc             five
# mercedes-benz        wagon       110.0   190.9         ohc             five
# mercedes-benz        sedan       120.9   208.1        ohcv            eight
# mercedes-benz      hardtop       112.0   199.2        ohcv            eight
# mitsubishi       hatchback        93.7   157.3         ohc             four
# mitsubishi       hatchback        93.7   157.3         ohc             four
# mitsubishi           sedan        96.3   172.4         ohc             four
# mitsubishi           sedan        96.3   172.4         ohc             four
# nissan               sedan        94.5   165.3         ohc             four
# nissan               sedan        94.5   165.3         ohc             four
# nissan               sedan        94.5   165.3         ohc             four
# nissan               wagon        94.5   170.2         ohc             four
# nissan               sedan       100.4   184.6        ohcv              six
# porsche            hardtop        89.5   168.9        ohcf              six
# porsche        convertible        89.5   168.9        ohcf              six
# toyota           hatchback        95.7   158.7         ohc             four
# toyota           hatchback        95.7   158.7         ohc             four
# toyota           hatchback        95.7   158.7         ohc             four
# toyota               wagon        95.7   169.7         ohc             four
# toyota               wagon        95.7   169.7         ohc             four
# toyota               wagon        95.7   169.7         ohc             four
# toyota               wagon       104.5   187.8        dohc              six
# volkswagen           sedan        97.3   171.7         ohc             four
# volkswagen           sedan        97.3   171.7         ohc             four
# volkswagen           sedan        97.3   171.7         ohc             four
# volkswagen           sedan        97.3   171.7         ohc             four
# volvo                sedan       104.3   188.8         ohc             four
# volvo                wagon       104.3   188.8         ohc             four
#
#                horsepower  average-mileage    price
# company
# alfa-romero           111             21.0  13495.0
# alfa-romero           154             19.0  16500.0
# audi                  102             24.0  13950.0
# audi                  115             18.0  17450.0
# audi                  110             19.0  15250.0
# audi                  110             19.0  18920.0
# bmw                   101             23.0  16430.0
# bmw                   101             23.0  16925.0
# bmw                   121             21.0  20970.0
# bmw                   182             16.0  30760.0
# bmw                   182             16.0  41315.0
# bmw                   182             15.0  36880.0
# chevrolet              48             47.0   5151.0
# chevrolet              70             38.0   6295.0
# chevrolet              70             38.0   6575.0
# dodge                  68             31.0   6377.0
# dodge                  68             31.0   6229.0
# honda                  76             30.0   7295.0
# honda                 101             24.0  12945.0
# honda                 100             25.0  10345.0
# isuzu                  78             24.0   6785.0
# jaguar                176             15.0  32250.0
# jaguar                176             15.0  35550.0
# jaguar                262             13.0  36000.0
# mazda                  68             30.0   5195.0
# mazda                  68             31.0   6095.0
# mazda                  68             31.0   6795.0
# mazda                 101             17.0  11845.0
# mazda                  72             31.0  18344.0
# mercedes-benz         123             22.0  25552.0
# mercedes-benz         123             22.0  28248.0
# mercedes-benz         184             14.0  40960.0
# mercedes-benz         184             14.0  45400.0
# mitsubishi             68             37.0   5389.0
# mitsubishi             68             31.0   6189.0
# mitsubishi             88             25.0   6989.0
# mitsubishi             88             25.0   8189.0
# nissan                 55             45.0   7099.0
# nissan                 69             31.0   6649.0
# nissan                 69             31.0   6849.0
# nissan                 69             31.0   7349.0
# nissan                152             19.0  13499.0
# porsche               207             17.0  34028.0
# porsche               207             17.0  37028.0
# toyota                 62             35.0   5348.0
# toyota                 62             31.0   6338.0
# toyota                 62             31.0   6488.0
# toyota                 62             31.0   6918.0
# toyota                 62             27.0   7898.0
# toyota                 62             27.0   8778.0
# toyota                156             19.0  15750.0
# volkswagen             52             37.0   7775.0
# volkswagen             85             27.0   7975.0
# volkswagen             52             37.0   7995.0
# volkswagen            100             26.0   9995.0
# volvo                 114             23.0  12940.0
# volvo                 114             23.0  13415.0

# %%
org_len = len(df)
new_len = len(df8)
null_rows_removed = org_len - new_len
null_rows_removed
# Out:
# 4

# %% [markdown]
# ## Iterating over rows using iteritems(), iterrows(), itertuples()

# %%
#using iterrows()
for i, j in df.iterrows():
    print(i, j)
    print()
# Out:
# alfa-romero body-style          convertible
# wheel-base                 88.6
# length                    168.8
# engine-type                dohc
# num-of-cylinders           four
# horsepower                  111
# average-mileage              21
# price                     13495
# Name: alfa-romero, dtype: object
#
# alfa-romero body-style          convertible
# wheel-base                 88.6
# length                    168.8
# engine-type                dohc
# num-of-cylinders           four
# horsepower                  111
# average-mileage             NaN
# price                     16500
# Name: alfa-romero, dtype: object
#
# alfa-romero body-style          hatchback
# wheel-base               94.5
# length                  171.2
# engine-type              ohcv
# num-of-cylinders          six
# horsepower                154
# average-mileage            19
# price                   16500
# Name: alfa-romero, dtype: object
#
# audi body-style          sedan
# wheel-base           99.8
# length              176.6
# engine-type           ohc
# num-of-cylinders     four
# horsepower            102
# average-mileage        24
# price               13950
# Name: audi, dtype: object
#
# audi body-style          sedan
# wheel-base           99.4
# length              176.6
# engine-type           ohc
# num-of-cylinders     five
# horsepower            115
# average-mileage        18
# price               17450
# Name: audi, dtype: object
#
# audi body-style          sedan
# wheel-base           99.8
# length              177.3
# engine-type           ohc
# num-of-cylinders     five
# horsepower            110
# average-mileage        19
# price               15250
# Name: audi, dtype: object
#
# audi body-style          wagon
# wheel-base          105.8
# length              192.7
# engine-type           ohc
# num-of-cylinders     five
# horsepower            110
# average-mileage        19
# price               18920
# Name: audi, dtype: object
#
# bmw body-style          sedan
# wheel-base          101.2
# length              176.8
# engine-type           ohc
# num-of-cylinders     four
# horsepower            101
# average-mileage        23
# price               16430
# Name: bmw, dtype: object
#
# bmw body-style          sedan
# wheel-base          101.2
# length              176.8
# engine-type           ohc
# num-of-cylinders     four
# horsepower            101
# average-mileage        23
# price               16925
# Name: bmw, dtype: object
#
# bmw body-style          sedan
# wheel-base          101.2
# length              176.8
# engine-type           ohc
# num-of-cylinders      six
# horsepower            121
# average-mileage        21
# price               20970
# Name: bmw, dtype: object
#
# bmw body-style          sedan
# wheel-base          103.5
# length                189
# engine-type           ohc
# num-of-cylinders      six
# horsepower            182
# average-mileage        16
# price               30760
# Name: bmw, dtype: object
#
# bmw body-style          sedan
# wheel-base          103.5
# length              193.8
# engine-type           ohc
# num-of-cylinders      six
# horsepower            182
# average-mileage        16
# price               41315
# Name: bmw, dtype: object
#
# bmw body-style          sedan
# wheel-base            110
# length                197
# engine-type           ohc
# num-of-cylinders      six
# horsepower            182
# average-mileage        15
# price               36880
# Name: bmw, dtype: object
#
# chevrolet body-style          hatchback
# wheel-base               88.4
# length                  141.1
# engine-type                 l
# num-of-cylinders        three
# horsepower                 48
# average-mileage            47
# price                    5151
# Name: chevrolet, dtype: object
#
# chevrolet body-style          hatchback
# wheel-base               94.5
# length                  155.9
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 70
# average-mileage            38
# price                    6295
# Name: chevrolet, dtype: object
#
# chevrolet body-style          sedan
# wheel-base           94.5
# length              158.8
# engine-type           ohc
# num-of-cylinders     four
# horsepower             70
# average-mileage        38
# price                6575
# Name: chevrolet, dtype: object
#
# dodge body-style          hatchback
# wheel-base               93.7
# length                  157.3
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            31
# price                    6377
# Name: dodge, dtype: object
#
# dodge body-style          hatchback
# wheel-base               93.7
# length                  157.3
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            31
# price                    6229
# Name: dodge, dtype: object
#
# honda body-style          wagon
# wheel-base           96.5
# length              157.1
# engine-type           ohc
# num-of-cylinders     four
# horsepower             76
# average-mileage        30
# price                7295
# Name: honda, dtype: object
#
# honda body-style          sedan
# wheel-base           96.5
# length              175.4
# engine-type           ohc
# num-of-cylinders     four
# horsepower            101
# average-mileage        24
# price               12945
# Name: honda, dtype: object
#
# honda body-style          sedan
# wheel-base           96.5
# length              169.1
# engine-type           ohc
# num-of-cylinders     four
# horsepower            100
# average-mileage        25
# price               10345
# Name: honda, dtype: object
#
# isuzu body-style          sedan
# wheel-base           94.3
# length              170.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower             78
# average-mileage        24
# price                6785
# Name: isuzu, dtype: object
#
# isuzu body-style          sedan
# wheel-base           94.5
# length              155.9
# engine-type           ohc
# num-of-cylinders     four
# horsepower             70
# average-mileage        38
# price                 NaN
# Name: isuzu, dtype: object
#
# isuzu body-style          sedan
# wheel-base           94.5
# length              155.9
# engine-type           ohc
# num-of-cylinders     four
# horsepower             70
# average-mileage        38
# price                 NaN
# Name: isuzu, dtype: object
#
# jaguar body-style          sedan
# wheel-base            113
# length              199.6
# engine-type          dohc
# num-of-cylinders      six
# horsepower            176
# average-mileage        15
# price               32250
# Name: jaguar, dtype: object
#
# jaguar body-style          sedan
# wheel-base            113
# length              199.6
# engine-type          dohc
# num-of-cylinders      six
# horsepower            176
# average-mileage        15
# price               35550
# Name: jaguar, dtype: object
#
# jaguar body-style           sedan
# wheel-base             102
# length               191.7
# engine-type           ohcv
# num-of-cylinders    twelve
# horsepower             262
# average-mileage         13
# price                36000
# Name: jaguar, dtype: object
#
# mazda body-style          hatchback
# wheel-base               93.1
# length                  159.1
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            30
# price                    5195
# Name: mazda, dtype: object
#
# mazda body-style          hatchback
# wheel-base               93.1
# length                  159.1
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            31
# price                    6095
# Name: mazda, dtype: object
#
# mazda body-style          hatchback
# wheel-base               93.1
# length                  159.1
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            31
# price                    6795
# Name: mazda, dtype: object
#
# mazda body-style          hatchback
# wheel-base               95.3
# length                    169
# engine-type             rotor
# num-of-cylinders          two
# horsepower                101
# average-mileage            17
# price                   11845
# Name: mazda, dtype: object
#
# mazda body-style          sedan
# wheel-base          104.9
# length                175
# engine-type           ohc
# num-of-cylinders     four
# horsepower             72
# average-mileage        31
# price               18344
# Name: mazda, dtype: object
#
# mercedes-benz body-style          sedan
# wheel-base            110
# length              190.9
# engine-type           ohc
# num-of-cylinders     five
# horsepower            123
# average-mileage        22
# price               25552
# Name: mercedes-benz, dtype: object
#
# mercedes-benz body-style          wagon
# wheel-base            110
# length              190.9
# engine-type           ohc
# num-of-cylinders     five
# horsepower            123
# average-mileage        22
# price               28248
# Name: mercedes-benz, dtype: object
#
# mercedes-benz body-style          sedan
# wheel-base          120.9
# length              208.1
# engine-type          ohcv
# num-of-cylinders    eight
# horsepower            184
# average-mileage        14
# price               40960
# Name: mercedes-benz, dtype: object
#
# mercedes-benz body-style          hardtop
# wheel-base              112
# length                199.2
# engine-type            ohcv
# num-of-cylinders      eight
# horsepower              184
# average-mileage          14
# price                 45400
# Name: mercedes-benz, dtype: object
#
# mitsubishi body-style          hatchback
# wheel-base               93.7
# length                  157.3
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            37
# price                    5389
# Name: mitsubishi, dtype: object
#
# mitsubishi body-style          hatchback
# wheel-base               93.7
# length                  157.3
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            31
# price                    6189
# Name: mitsubishi, dtype: object
#
# mitsubishi body-style          sedan
# wheel-base           96.3
# length              172.4
# engine-type           ohc
# num-of-cylinders     four
# horsepower             88
# average-mileage        25
# price                6989
# Name: mitsubishi, dtype: object
#
# mitsubishi body-style          sedan
# wheel-base           96.3
# length              172.4
# engine-type           ohc
# num-of-cylinders     four
# horsepower             88
# average-mileage        25
# price                8189
# Name: mitsubishi, dtype: object
#
# nissan body-style          sedan
# wheel-base           94.5
# length              165.3
# engine-type           ohc
# num-of-cylinders     four
# horsepower             55
# average-mileage        45
# price                7099
# Name: nissan, dtype: object
#
# nissan body-style          sedan
# wheel-base           94.5
# length              165.3
# engine-type           ohc
# num-of-cylinders     four
# horsepower             69
# average-mileage        31
# price                6649
# Name: nissan, dtype: object
#
# nissan body-style          sedan
# wheel-base           94.5
# length              165.3
# engine-type           ohc
# num-of-cylinders     four
# horsepower             69
# average-mileage        31
# price                6849
# Name: nissan, dtype: object
#
# nissan body-style          wagon
# wheel-base           94.5
# length              170.2
# engine-type           ohc
# num-of-cylinders     four
# horsepower             69
# average-mileage        31
# price                7349
# Name: nissan, dtype: object
#
# nissan body-style          sedan
# wheel-base          100.4
# length              184.6
# engine-type          ohcv
# num-of-cylinders      six
# horsepower            152
# average-mileage        19
# price               13499
# Name: nissan, dtype: object
#
# porsche body-style          hardtop
# wheel-base             89.5
# length                168.9
# engine-type            ohcf
# num-of-cylinders        six
# horsepower              207
# average-mileage          17
# price                 34028
# Name: porsche, dtype: object
#
# porsche body-style          convertible
# wheel-base                 89.5
# length                    168.9
# engine-type                ohcf
# num-of-cylinders            six
# horsepower                  207
# average-mileage              17
# price                     37028
# Name: porsche, dtype: object
#
# porsche body-style          hatchback
# wheel-base               98.4
# length                  175.7
# engine-type             dohcv
# num-of-cylinders        eight
# horsepower                288
# average-mileage            17
# price                     NaN
# Name: porsche, dtype: object
#
# toyota body-style          hatchback
# wheel-base               95.7
# length                  158.7
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 62
# average-mileage            35
# price                    5348
# Name: toyota, dtype: object
#
# toyota body-style          hatchback
# wheel-base               95.7
# length                  158.7
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 62
# average-mileage            31
# price                    6338
# Name: toyota, dtype: object
#
# toyota body-style          hatchback
# wheel-base               95.7
# length                  158.7
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 62
# average-mileage            31
# price                    6488
# Name: toyota, dtype: object
#
# toyota body-style          wagon
# wheel-base           95.7
# length              169.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower             62
# average-mileage        31
# price                6918
# Name: toyota, dtype: object
#
# toyota body-style          wagon
# wheel-base           95.7
# length              169.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower             62
# average-mileage        27
# price                7898
# Name: toyota, dtype: object
#
# toyota body-style          wagon
# wheel-base           95.7
# length              169.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower             62
# average-mileage        27
# price                8778
# Name: toyota, dtype: object
#
# toyota body-style          wagon
# wheel-base          104.5
# length              187.8
# engine-type          dohc
# num-of-cylinders      six
# horsepower            156
# average-mileage        19
# price               15750
# Name: toyota, dtype: object
#
# volkswagen body-style          sedan
# wheel-base           97.3
# length              171.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower             52
# average-mileage        37
# price                7775
# Name: volkswagen, dtype: object
#
# volkswagen body-style          sedan
# wheel-base           97.3
# length              171.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower             85
# average-mileage        27
# price                7975
# Name: volkswagen, dtype: object
#
# volkswagen body-style          sedan
# wheel-base           97.3
# length              171.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower             52
# average-mileage        37
# price                7995
# Name: volkswagen, dtype: object
#
# volkswagen body-style          sedan
# wheel-base           97.3
# length              171.7
# engine-type           ohc
# num-of-cylinders     four
# horsepower            100
# average-mileage        26
# price                9995
# Name: volkswagen, dtype: object
#
# volvo body-style          sedan
# wheel-base          104.3
# length              188.8
# engine-type           ohc
# num-of-cylinders     four
# horsepower            114
# average-mileage        23
# price               12940
# Name: volvo, dtype: object
#
# volvo body-style          wagon
# wheel-base          104.3
# length              188.8
# engine-type           ohc
# num-of-cylinders     four
# horsepower            114
# average-mileage        23
# price               13415
# Name: volvo, dtype: object

# %%
df = pd.read_csv('Automobile_data.csv')

#Iterate over columns
columns = list(df)
 
for i in columns:
        print (df[i][4]) #fifth row
# Out:
# audi
# sedan
# 99.4
# 176.6
# ohc
# five
# 115
# 18.0
# 17450.0

# %%
#using iteritems()

for key, value in df.iteritems():
    print(key, value)
# Out:
# company 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
#          ...
# 56     volkswagen
# 57     volkswagen
# 58     volkswagen
# 59          volvo
# 60          volvo
# Name: company, Length: 61, dtype: object
# body-style 0     convertible
# 1     convertible
# 2       hatchback
# 3           sedan
# 4           sedan
#          ...
# 56          sedan
# 57          sedan
# 58          sedan
# 59          sedan
# 60          wagon
# Name: body-style, Length: 61, dtype: object
# wheel-base 0      88.6
# 1      88.6
# 2      94.5
# 3      99.8
# 4      99.4
#       ...
# 56     97.3
# 57     97.3
# 58     97.3
# 59    104.3
# 60    104.3
# Name: wheel-base, Length: 61, dtype: float64
# length 0     168.8
# 1     168.8
# 2     171.2
# 3     176.6
# 4     176.6
#       ...
# 56    171.7
# 57    171.7
# 58    171.7
# 59    188.8
# 60    188.8
# Name: length, Length: 61, dtype: float64
# engine-type 0     dohc
# 1     dohc
# 2     ohcv
# 3      ohc
# 4      ohc
#       ...
# 56     ohc
# 57     ohc
# 58     ohc
# 59     ohc
# 60     ohc
# Name: engine-type, Length: 61, dtype: object
# num-of-cylinders 0     four
# 1     four
# 2      six
# 3     four
# 4     five
#       ...
# 56    four
# 57    four
# 58    four
# 59    four
# 60    four
# Name: num-of-cylinders, Length: 61, dtype: object
# horsepower 0     111
# 1     111
# 2     154
# 3     102
# 4     115
#      ...
# 56     85
# 57     52
# 58    100
# 59    114
# 60    114
# Name: horsepower, Length: 61, dtype: int64
# average-mileage 0     21.0
# 1      NaN
# 2     19.0
# 3     24.0
# 4     18.0
#       ...
# 56    27.0
# 57    37.0
# 58    26.0
# 59    23.0
# 60    23.0
# Name: average-mileage, Length: 61, dtype: float64
# price 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
#using itertuples()

for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=0, company='alfa-romero', _2='convertible', _3=88.6, length=168.8, _5='dohc', _6='four', horsepower=111, _8=21.0, price=13495.0)
# Pandas(Index=1, company='alfa-romero', _2='convertible', _3=88.6, length=168.8, _5='dohc', _6='four', horsepower=111, _8=nan, price=16500.0)
# Pandas(Index=2, company='alfa-romero', _2='hatchback', _3=94.5, length=171.2, _5='ohcv', _6='six', horsepower=154, _8=19.0, price=16500.0)
# Pandas(Index=3, company='audi', _2='sedan', _3=99.8, length=176.6, _5='ohc', _6='four', horsepower=102, _8=24.0, price=13950.0)
# Pandas(Index=4, company='audi', _2='sedan', _3=99.4, length=176.6, _5='ohc', _6='five', horsepower=115, _8=18.0, price=17450.0)
# Pandas(Index=5, company='audi', _2='sedan', _3=99.8, length=177.3, _5='ohc', _6='five', horsepower=110, _8=19.0, price=15250.0)
# Pandas(Index=6, company='audi', _2='wagon', _3=105.8, length=192.7, _5='ohc', _6='five', horsepower=110, _8=19.0, price=18920.0)
# Pandas(Index=7, company='bmw', _2='sedan', _3=101.2, length=176.8, _5='ohc', _6='four', horsepower=101, _8=23.0, price=16430.0)
# Pandas(Index=8, company='bmw', _2='sedan', _3=101.2, length=176.8, _5='ohc', _6='four', horsepower=101, _8=23.0, price=16925.0)
# Pandas(Index=9, company='bmw', _2='sedan', _3=101.2, length=176.8, _5='ohc', _6='six', horsepower=121, _8=21.0, price=20970.0)
# Pandas(Index=10, company='bmw', _2='sedan', _3=103.5, length=189.0, _5='ohc', _6='six', horsepower=182, _8=16.0, price=30760.0)
# Pandas(Index=11, company='bmw', _2='sedan', _3=103.5, length=193.8, _5='ohc', _6='six', horsepower=182, _8=16.0, price=41315.0)
# Pandas(Index=12, company='bmw', _2='sedan', _3=110.0, length=197.0, _5='ohc', _6='six', horsepower=182, _8=15.0, price=36880.0)
# Pandas(Index=13, company='chevrolet', _2='hatchback', _3=88.4, length=141.1, _5='l', _6='three', horsepower=48, _8=47.0, price=5151.0)
# Pandas(Index=14, company='chevrolet', _2='hatchback', _3=94.5, length=155.9, _5='ohc', _6='four', horsepower=70, _8=38.0, price=6295.0)
# Pandas(Index=15, company='chevrolet', _2='sedan', _3=94.5, length=158.8, _5='ohc', _6='four', horsepower=70, _8=38.0, price=6575.0)
# Pandas(Index=16, company='dodge', _2='hatchback', _3=93.7, length=157.3, _5='ohc', _6='four', horsepower=68, _8=31.0, price=6377.0)
# Pandas(Index=17, company='dodge', _2='hatchback', _3=93.7, length=157.3, _5='ohc', _6='four', horsepower=68, _8=31.0, price=6229.0)
# Pandas(Index=18, company='honda', _2='wagon', _3=96.5, length=157.1, _5='ohc', _6='four', horsepower=76, _8=30.0, price=7295.0)
# Pandas(Index=19, company='honda', _2='sedan', _3=96.5, length=175.4, _5='ohc', _6='four', horsepower=101, _8=24.0, price=12945.0)
# Pandas(Index=20, company='honda', _2='sedan', _3=96.5, length=169.1, _5='ohc', _6='four', horsepower=100, _8=25.0, price=10345.0)
# Pandas(Index=21, company='isuzu', _2='sedan', _3=94.3, length=170.7, _5='ohc', _6='four', horsepower=78, _8=24.0, price=6785.0)
# Pandas(Index=22, company='isuzu', _2='sedan', _3=94.5, length=155.9, _5='ohc', _6='four', horsepower=70, _8=38.0, price=nan)
# Pandas(Index=23, company='isuzu', _2='sedan', _3=94.5, length=155.9, _5='ohc', _6='four', horsepower=70, _8=38.0, price=nan)
# Pandas(Index=24, company='jaguar', _2='sedan', _3=113.0, length=199.6, _5='dohc', _6='six', horsepower=176, _8=15.0, price=32250.0)
# Pandas(Index=25, company='jaguar', _2='sedan', _3=113.0, length=199.6, _5='dohc', _6='six', horsepower=176, _8=15.0, price=35550.0)
# Pandas(Index=26, company='jaguar', _2='sedan', _3=102.0, length=191.7, _5='ohcv', _6='twelve', horsepower=262, _8=13.0, price=36000.0)
# Pandas(Index=27, company='mazda', _2='hatchback', _3=93.1, length=159.1, _5='ohc', _6='four', horsepower=68, _8=30.0, price=5195.0)
# Pandas(Index=28, company='mazda', _2='hatchback', _3=93.1, length=159.1, _5='ohc', _6='four', horsepower=68, _8=31.0, price=6095.0)
# Pandas(Index=29, company='mazda', _2='hatchback', _3=93.1, length=159.1, _5='ohc', _6='four', horsepower=68, _8=31.0, price=6795.0)
# Pandas(Index=30, company='mazda', _2='hatchback', _3=95.3, length=169.0, _5='rotor', _6='two', horsepower=101, _8=17.0, price=11845.0)
# Pandas(Index=31, company='mazda', _2='sedan', _3=104.9, length=175.0, _5='ohc', _6='four', horsepower=72, _8=31.0, price=18344.0)
# Pandas(Index=32, company='mercedes-benz', _2='sedan', _3=110.0, length=190.9, _5='ohc', _6='five', horsepower=123, _8=22.0, price=25552.0)
# Pandas(Index=33, company='mercedes-benz', _2='wagon', _3=110.0, length=190.9, _5='ohc', _6='five', horsepower=123, _8=22.0, price=28248.0)
# Pandas(Index=34, company='mercedes-benz', _2='sedan', _3=120.9, length=208.1, _5='ohcv', _6='eight', horsepower=184, _8=14.0, price=40960.0)
# Pandas(Index=35, company='mercedes-benz', _2='hardtop', _3=112.0, length=199.2, _5='ohcv', _6='eight', horsepower=184, _8=14.0, price=45400.0)
# Pandas(Index=36, company='mitsubishi', _2='hatchback', _3=93.7, length=157.3, _5='ohc', _6='four', horsepower=68, _8=37.0, price=5389.0)
# Pandas(Index=37, company='mitsubishi', _2='hatchback', _3=93.7, length=157.3, _5='ohc', _6='four', horsepower=68, _8=31.0, price=6189.0)
# Pandas(Index=38, company='mitsubishi', _2='sedan', _3=96.3, length=172.4, _5='ohc', _6='four', horsepower=88, _8=25.0, price=6989.0)
# Pandas(Index=39, company='mitsubishi', _2='sedan', _3=96.3, length=172.4, _5='ohc', _6='four', horsepower=88, _8=25.0, price=8189.0)
# Pandas(Index=40, company='nissan', _2='sedan', _3=94.5, length=165.3, _5='ohc', _6='four', horsepower=55, _8=45.0, price=7099.0)
# Pandas(Index=41, company='nissan', _2='sedan', _3=94.5, length=165.3, _5='ohc', _6='four', horsepower=69, _8=31.0, price=6649.0)
# Pandas(Index=42, company='nissan', _2='sedan', _3=94.5, length=165.3, _5='ohc', _6='four', horsepower=69, _8=31.0, price=6849.0)
# Pandas(Index=43, company='nissan', _2='wagon', _3=94.5, length=170.2, _5='ohc', _6='four', horsepower=69, _8=31.0, price=7349.0)
# Pandas(Index=44, company='nissan', _2='sedan', _3=100.4, length=184.6, _5='ohcv', _6='six', horsepower=152, _8=19.0, price=13499.0)
# Pandas(Index=45, company='porsche', _2='hardtop', _3=89.5, length=168.9, _5='ohcf', _6='six', horsepower=207, _8=17.0, price=34028.0)
# Pandas(Index=46, company='porsche', _2='convertible', _3=89.5, length=168.9, _5='ohcf', _6='six', horsepower=207, _8=17.0, price=37028.0)
# Pandas(Index=47, company='porsche', _2='hatchback', _3=98.4, length=175.7, _5='dohcv', _6='eight', horsepower=288, _8=17.0, price=nan)
# Pandas(Index=48, company='toyota', _2='hatchback', _3=95.7, length=158.7, _5='ohc', _6='four', horsepower=62, _8=35.0, price=5348.0)
# Pandas(Index=49, company='toyota', _2='hatchback', _3=95.7, length=158.7, _5='ohc', _6='four', horsepower=62, _8=31.0, price=6338.0)
# Pandas(Index=50, company='toyota', _2='hatchback', _3=95.7, length=158.7, _5='ohc', _6='four', horsepower=62, _8=31.0, price=6488.0)
# Pandas(Index=51, company='toyota', _2='wagon', _3=95.7, length=169.7, _5='ohc', _6='four', horsepower=62, _8=31.0, price=6918.0)
# Pandas(Index=52, company='toyota', _2='wagon', _3=95.7, length=169.7, _5='ohc', _6='four', horsepower=62, _8=27.0, price=7898.0)
# Pandas(Index=53, company='toyota', _2='wagon', _3=95.7, length=169.7, _5='ohc', _6='four', horsepower=62, _8=27.0, price=8778.0)
# Pandas(Index=54, company='toyota', _2='wagon', _3=104.5, length=187.8, _5='dohc', _6='six', horsepower=156, _8=19.0, price=15750.0)
# Pandas(Index=55, company='volkswagen', _2='sedan', _3=97.3, length=171.7, _5='ohc', _6='four', horsepower=52, _8=37.0, price=7775.0)
# Pandas(Index=56, company='volkswagen', _2='sedan', _3=97.3, length=171.7, _5='ohc', _6='four', horsepower=85, _8=27.0, price=7975.0)
# Pandas(Index=57, company='volkswagen', _2='sedan', _3=97.3, length=171.7, _5='ohc', _6='four', horsepower=52, _8=37.0, price=7995.0)
# Pandas(Index=58, company='volkswagen', _2='sedan', _3=97.3, length=171.7, _5='ohc', _6='four', horsepower=100, _8=26.0, price=9995.0)
# Pandas(Index=59, company='volvo', _2='sedan', _3=104.3, length=188.8, _5='ohc', _6='four', horsepower=114, _8=23.0, price=12940.0)
# Pandas(Index=60, company='volvo', _2='wagon', _3=104.3, length=188.8, _5='ohc', _6='four', horsepower=114, _8=23.0, price=13415.0)

# %% [markdown]
# ## DataFrame Methods

# %%
# dataframe.index 

df = pd.read_csv('Automobile_data.csv')
df.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
# DataFrameName.insert(loc, column, value, allow_duplicates = False)

df.insert(8,'new column','a')
df.columns
# Out:
# Index(['company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'new column',
#        'price'],
#       dtype='object')

# %%
df.head(10)
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3         audi        sedan        99.8   176.6         ohc             four
# 4         audi        sedan        99.4   176.6         ohc             five
# 5         audi        sedan        99.8   177.3         ohc             five
# 6         audi        wagon       105.8   192.7         ohc             five
# 7          bmw        sedan       101.2   176.8         ohc             four
# 8          bmw        sedan       101.2   176.8         ohc             four
# 9          bmw        sedan       101.2   176.8         ohc              six
#
#    horsepower  average-mileage new column    price
# 0         111             21.0          a  13495.0
# 1         111              NaN          a  16500.0
# 2         154             19.0          a  16500.0
# 3         102             24.0          a  13950.0
# 4         115             18.0          a  17450.0
# 5         110             19.0          a  15250.0
# 6         110             19.0          a  18920.0
# 7         101             23.0          a  16430.0
# 8         101             23.0          a  16925.0
# 9         121             21.0          a  20970.0

# %%
#DataFrame.add(other, axis=’columns’, level=None, fill_value=None)

# Importing Pandas as pd
import pandas as pd

# Importing numpy as np
import numpy as np

# Creating a dataframe
# Setting the seed value to re-generate the result.
np.random.seed(25)

dataframe = pd.DataFrame(np.random.rand(5, 3), columns =['A', 'B', 'C'])

# np.random.rand(5, 3) has generated a
# random 2-Dimensional array of shape 5 * 3
# which is then converted to a dataframe

dataframe
# Out:
#           A         B         C
# 0  0.870124  0.582277  0.278839
# 1  0.185911  0.411100  0.117376
# 2  0.684969  0.437611  0.556229
# 3  0.367080  0.402366  0.113041
# 4  0.447031  0.585445  0.161985

# %%
dataframe.iloc[-1] = np.nan #Null values at the end
dataframe
# Out:
#           A         B         C
# 0  0.870124  0.582277  0.278839
# 1  0.185911  0.411100  0.117376
# 2  0.684969  0.437611  0.556229
# 3  0.367080  0.402366  0.113041
# 4       NaN       NaN       NaN

# %%
dt = dataframe.add(1, fill_value = 10)

# %%
# DataFrame.sub(other, axis=’columns’, level=None, fill_value=None)

sub1 = dt.sub(1)
sub1
# Out:
#            A          B          C
# 0   0.870124   0.582277   0.278839
# 1   0.185911   0.411100   0.117376
# 2   0.684969   0.437611   0.556229
# 3   0.367080   0.402366   0.113041
# 4  10.000000  10.000000  10.000000

# %%
# DataFrame.mul(other, axis=’columns’, level=None, fill_value=None)

mul1 = sub1.mul(2)
mul1
# Out:
#            A          B          C
# 0   1.740248   1.164554   0.557678
# 1   0.371822   0.822200   0.234751
# 2   1.369937   0.875222   1.112459
# 3   0.734161   0.804731   0.226081
# 4  20.000000  20.000000  20.000000

# %%
# DataFrame.div(other, axis=’columns’, level=None, fill_value=None)

div1 = mul1.div(2)
div1
# Out:
#            A          B          C
# 0   0.870124   0.582277   0.278839
# 1   0.185911   0.411100   0.117376
# 2   0.684969   0.437611   0.556229
# 3   0.367080   0.402366   0.113041
# 4  10.000000  10.000000  10.000000

# %%
# unique() Method extracts the unique values in the dataframe

df = pd.read_csv('Automobile_data.csv')
unique_comp = df['company'].unique()
unique_comp
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mitsubishi',
#        'nissan', 'porsche', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# nunique() Method returns count of the unique values in the dataframe

df = pd.read_csv('Automobile_data.csv')
no_unique_comp = df['company'].nunique()
no_unique_comp
# Out:
# 16

# %%
# value_counts() Method counts the number of times each unique value occurs within the Series

df = pd.read_csv('Automobile_data.csv')
no_of_times = df['company'].value_counts()
no_of_times
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# mitsubishi       4
# mercedes-benz    4
# audi             4
# volkswagen       4
# jaguar           3
# isuzu            3
# alfa-romero      3
# honda            3
# porsche          3
# chevrolet        3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
# columns the column labels of the DataFrame
col = df.columns
col
# Out:
# Index(['company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
# axes a list representing the axes of the DataFrame

axes = df.axes
axes
# Out:
# [RangeIndex(start=0, stop=61, step=1),
#  Index(['company', 'body-style', 'wheel-base', 'length', 'engine-type',
#         'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#        dtype='object')]

# %%
# between(start, end)

btw = df['price'].between(10000,15000) # price between 10000 - 15000
btw
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59     True
# 60     True
# Name: price, Length: 61, dtype: bool

# %%
# DataFrame.isin(values)

req_comp = df['company'].isin(['alfa-romero','bmw'])
req_comp.head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: company, dtype: bool

# %%
# DataFrame.dtypes - data type of each column.

df.dtypes
# Out:
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage     float64
# price               float64
# dtype: object

# %%
# values() Method returns a Numpy representation of the DataFrame i.e. only the values in the DataFrame will be returned, the axes labels will be removed

value_df = df.values
value_df
# Out:
# array([['alfa-romero', 'convertible', 88.6, 168.8, 'dohc', 'four', 111,
#         21.0, 13495.0],
#        ['alfa-romero', 'convertible', 88.6, 168.8, 'dohc', 'four', 111,
#         nan, 16500.0],
#        ['alfa-romero', 'hatchback', 94.5, 171.2, 'ohcv', 'six', 154,
#         19.0, 16500.0],
#        ['audi', 'sedan', 99.8, 176.6, 'ohc', 'four', 102, 24.0, 13950.0],
#        ['audi', 'sedan', 99.4, 176.6, 'ohc', 'five', 115, 18.0, 17450.0],
#        ['audi', 'sedan', 99.8, 177.3, 'ohc', 'five', 110, 19.0, 15250.0],
#        ['audi', 'wagon', 105.8, 192.7, 'ohc', 'five', 110, 19.0, 18920.0],
#        ['bmw', 'sedan', 101.2, 176.8, 'ohc', 'four', 101, 23.0, 16430.0],
#        ['bmw', 'sedan', 101.2, 176.8, 'ohc', 'four', 101, 23.0, 16925.0],
#        ['bmw', 'sedan', 101.2, 176.8, 'ohc', 'six', 121, 21.0, 20970.0],
#        ['bmw', 'sedan', 103.5, 189.0, 'ohc', 'six', 182, 16.0, 30760.0],
#        ['bmw', 'sedan', 103.5, 193.8, 'ohc', 'six', 182, 16.0, 41315.0],
#        ['bmw', 'sedan', 110.0, 197.0, 'ohc', 'six', 182, 15.0, 36880.0],
#        ['chevrolet', 'hatchback', 88.4, 141.1, 'l', 'three', 48, 47.0,
#         5151.0],
#        ['chevrolet', 'hatchback', 94.5, 155.9, 'ohc', 'four', 70, 38.0,
#         6295.0],
#        ['chevrolet', 'sedan', 94.5, 158.8, 'ohc', 'four', 70, 38.0,
#         6575.0],
#        ['dodge', 'hatchback', 93.7, 157.3, 'ohc', 'four', 68, 31.0,
#         6377.0],
#        ['dodge', 'hatchback', 93.7, 157.3, 'ohc', 'four', 68, 31.0,
#         6229.0],
#        ['honda', 'wagon', 96.5, 157.1, 'ohc', 'four', 76, 30.0, 7295.0],
#        ['honda', 'sedan', 96.5, 175.4, 'ohc', 'four', 101, 24.0, 12945.0],
#        ['honda', 'sedan', 96.5, 169.1, 'ohc', 'four', 100, 25.0, 10345.0],
#        ['isuzu', 'sedan', 94.3, 170.7, 'ohc', 'four', 78, 24.0, 6785.0],
#        ['isuzu', 'sedan', 94.5, 155.9, 'ohc', 'four', 70, 38.0, nan],
#        ['isuzu', 'sedan', 94.5, 155.9, 'ohc', 'four', 70, 38.0, nan],
#        ['jaguar', 'sedan', 113.0, 199.6, 'dohc', 'six', 176, 15.0,
#         32250.0],
#        ['jaguar', 'sedan', 113.0, 199.6, 'dohc', 'six', 176, 15.0,
#         35550.0],
#        ['jaguar', 'sedan', 102.0, 191.7, 'ohcv', 'twelve', 262, 13.0,
#         36000.0],
#        ['mazda', 'hatchback', 93.1, 159.1, 'ohc', 'four', 68, 30.0,
#         5195.0],
#        ['mazda', 'hatchback', 93.1, 159.1, 'ohc', 'four', 68, 31.0,
#         6095.0],
#        ['mazda', 'hatchback', 93.1, 159.1, 'ohc', 'four', 68, 31.0,
#         6795.0],
#        ['mazda', 'hatchback', 95.3, 169.0, 'rotor', 'two', 101, 17.0,
#         11845.0],
#        ['mazda', 'sedan', 104.9, 175.0, 'ohc', 'four', 72, 31.0, 18344.0],
#        ['mercedes-benz', 'sedan', 110.0, 190.9, 'ohc', 'five', 123, 22.0,
#         25552.0],
#        ['mercedes-benz', 'wagon', 110.0, 190.9, 'ohc', 'five', 123, 22.0,
#         28248.0],
#        ['mercedes-benz', 'sedan', 120.9, 208.1, 'ohcv', 'eight', 184,
#         14.0, 40960.0],
#        ['mercedes-benz', 'hardtop', 112.0, 199.2, 'ohcv', 'eight', 184,
#         14.0, 45400.0],
#        ['mitsubishi', 'hatchback', 93.7, 157.3, 'ohc', 'four', 68, 37.0,
#         5389.0],
#        ['mitsubishi', 'hatchback', 93.7, 157.3, 'ohc', 'four', 68, 31.0,
#         6189.0],
#        ['mitsubishi', 'sedan', 96.3, 172.4, 'ohc', 'four', 88, 25.0,
#         6989.0],
#        ['mitsubishi', 'sedan', 96.3, 172.4, 'ohc', 'four', 88, 25.0,
#         8189.0],
#        ['nissan', 'sedan', 94.5, 165.3, 'ohc', 'four', 55, 45.0, 7099.0],
#        ['nissan', 'sedan', 94.5, 165.3, 'ohc', 'four', 69, 31.0, 6649.0],
#        ['nissan', 'sedan', 94.5, 165.3, 'ohc', 'four', 69, 31.0, 6849.0],
#        ['nissan', 'wagon', 94.5, 170.2, 'ohc', 'four', 69, 31.0, 7349.0],
#        ['nissan', 'sedan', 100.4, 184.6, 'ohcv', 'six', 152, 19.0,
#         13499.0],
#        ['porsche', 'hardtop', 89.5, 168.9, 'ohcf', 'six', 207, 17.0,
#         34028.0],
#        ['porsche', 'convertible', 89.5, 168.9, 'ohcf', 'six', 207, 17.0,
#         37028.0],
#        ['porsche', 'hatchback', 98.4, 175.7, 'dohcv', 'eight', 288, 17.0,
#         nan],
#        ['toyota', 'hatchback', 95.7, 158.7, 'ohc', 'four', 62, 35.0,
#         5348.0],
#        ['toyota', 'hatchback', 95.7, 158.7, 'ohc', 'four', 62, 31.0,
#         6338.0],
#        ['toyota', 'hatchback', 95.7, 158.7, 'ohc', 'four', 62, 31.0,
#         6488.0],
#        ['toyota', 'wagon', 95.7, 169.7, 'ohc', 'four', 62, 31.0, 6918.0],
#        ['toyota', 'wagon', 95.7, 169.7, 'ohc', 'four', 62, 27.0, 7898.0],
#        ['toyota', 'wagon', 95.7, 169.7, 'ohc', 'four', 62, 27.0, 8778.0],
#        ['toyota', 'wagon', 104.5, 187.8, 'dohc', 'six', 156, 19.0,
#         15750.0],
#        ['volkswagen', 'sedan', 97.3, 171.7, 'ohc', 'four', 52, 37.0,
#         7775.0],
#        ['volkswagen', 'sedan', 97.3, 171.7, 'ohc', 'four', 85, 27.0,
#         7975.0],
#        ['volkswagen', 'sedan', 97.3, 171.7, 'ohc', 'four', 52, 37.0,
#         7995.0],
#        ['volkswagen', 'sedan', 97.3, 171.7, 'ohc', 'four', 100, 26.0,
#         9995.0],
#        ['volvo', 'sedan', 104.3, 188.8, 'ohc', 'four', 114, 23.0,
#         12940.0],
#        ['volvo', 'wagon', 104.3, 188.8, 'ohc', 'four', 114, 23.0,
#         13415.0]], dtype=object)

# %%
# sort_values() Method sorts a data frame in Ascending or Descending order of passed Column
#DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind=’quicksort’, na_position=’last’)

sorted_values = df.sort_values(['company','price'], ascending=[False,True])
sorted_values.head()
# Out:
#        company body-style  wheel-base  length engine-type num-of-cylinders  \
# 59       volvo      sedan       104.3   188.8         ohc             four
# 60       volvo      wagon       104.3   188.8         ohc             four
# 55  volkswagen      sedan        97.3   171.7         ohc             four
# 56  volkswagen      sedan        97.3   171.7         ohc             four
# 57  volkswagen      sedan        97.3   171.7         ohc             four
#
#     horsepower  average-mileage    price
# 59         114             23.0  12940.0
# 60         114             23.0  13415.0
# 55          52             37.0   7775.0
# 56          85             27.0   7975.0
# 57          52             37.0   7995.0

# %%
# DataFrame.sort_index(axis=0, level=None, ascending=True, inplace=False, kind=’quicksort’, na_position=’last’, sort_remaining=True, by=None)

df1 = pd.read_csv('Automobile_data.csv', index_col = 'body-style')

sorted_indx = df1.sort_index(axis=0)
sorted_indx.head()
# Out:
#                    company  wheel-base  length engine-type num-of-cylinders  \
# body-style
# convertible    alfa-romero        88.6   168.8        dohc             four
# convertible    alfa-romero        88.6   168.8        dohc             four
# convertible        porsche        89.5   168.9        ohcf              six
# hardtop            porsche        89.5   168.9        ohcf              six
# hardtop      mercedes-benz       112.0   199.2        ohcv            eight
#
#              horsepower  average-mileage    price
# body-style
# convertible         111             21.0  13495.0
# convertible         111              NaN  16500.0
# convertible         207             17.0  37028.0
# hardtop             207             17.0  34028.0
# hardtop             184             14.0  45400.0

# %%
# rename() Method is called on a DataFrame to change the names of the index labels or column names
# DataFrame.rename(mapper=None, index=None, columns=None, axis=None, copy=True, inplace=False, level=None)

df = pd.read_csv('Automobile_data.csv')
new_df = df.rename(columns={'body-style':'body_style', 'engine-type': 'engine_type'})
new_df
# Out:
#         company   body_style  wheel-base  length engine_type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 0          111             21.0  13495.0
# 1          111              NaN  16500.0
# 2          154             19.0  16500.0
# 3          102             24.0  13950.0
# 4          115             18.0  17450.0
# ..         ...              ...      ...
# 56          85             27.0   7975.0
# 57          52             37.0   7995.0
# 58         100             26.0   9995.0
# 59         114             23.0  12940.0
# 60         114             23.0  13415.0
#
# [61 rows x 9 columns]

# %%
df
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 0          111             21.0  13495.0
# 1          111              NaN  16500.0
# 2          154             19.0  16500.0
# 3          102             24.0  13950.0
# 4          115             18.0  17450.0
# ..         ...              ...      ...
# 56          85             27.0   7975.0
# 57          52             37.0   7995.0
# 58         100             26.0   9995.0
# 59         114             23.0  12940.0
# 60         114             23.0  13415.0
#
# [61 rows x 9 columns]

# %%
# DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors=’raise’)

#dropping columns by index label

drop_df = df.drop(['wheel-base'], axis = 1)
drop_df
# Out:
#         company   body-style  length engine-type num-of-cylinders  horsepower  \
# 0   alfa-romero  convertible   168.8        dohc             four         111
# 1   alfa-romero  convertible   168.8        dohc             four         111
# 2   alfa-romero    hatchback   171.2        ohcv              six         154
# 3          audi        sedan   176.6         ohc             four         102
# 4          audi        sedan   176.6         ohc             five         115
# ..          ...          ...     ...         ...              ...         ...
# 56   volkswagen        sedan   171.7         ohc             four          85
# 57   volkswagen        sedan   171.7         ohc             four          52
# 58   volkswagen        sedan   171.7         ohc             four         100
# 59        volvo        sedan   188.8         ohc             four         114
# 60        volvo        wagon   188.8         ohc             four         114
#
#     average-mileage    price
# 0              21.0  13495.0
# 1               NaN  16500.0
# 2              19.0  16500.0
# 3              24.0  13950.0
# 4              18.0  17450.0
# ..              ...      ...
# 56             27.0   7975.0
# 57             37.0   7995.0
# 58             26.0   9995.0
# 59             23.0  12940.0
# 60             23.0  13415.0
#
# [61 rows x 8 columns]

# %%
#dropping rows by index label

drop_df = df.drop([0,1,8], axis = 0)
drop_df.head(10)
# Out:
#         company body-style  wheel-base  length engine-type num-of-cylinders  \
# 2   alfa-romero  hatchback        94.5   171.2        ohcv              six
# 3          audi      sedan        99.8   176.6         ohc             four
# 4          audi      sedan        99.4   176.6         ohc             five
# 5          audi      sedan        99.8   177.3         ohc             five
# 6          audi      wagon       105.8   192.7         ohc             five
# 7           bmw      sedan       101.2   176.8         ohc             four
# 9           bmw      sedan       101.2   176.8         ohc              six
# 10          bmw      sedan       103.5   189.0         ohc              six
# 11          bmw      sedan       103.5   193.8         ohc              six
# 12          bmw      sedan       110.0   197.0         ohc              six
#
#     horsepower  average-mileage    price
# 2          154             19.0  16500.0
# 3          102             24.0  13950.0
# 4          115             18.0  17450.0
# 5          110             19.0  15250.0
# 6          110             19.0  18920.0
# 7          101             23.0  16430.0
# 9          121             21.0  20970.0
# 10         182             16.0  30760.0
# 11         182             16.0  41315.0
# 12         182             15.0  36880.0

# %%
# DataFrame.pop(item) is used to delete rows or columns from a DataFrame

popped_col = df.pop("length")
popped_col
# Out:
# 0     168.8
# 1     168.8
# 2     171.2
# 3     176.6
# 4     176.6
#       ...
# 56    171.7
# 57    171.7
# 58    171.7
# 59    188.8
# 60    188.8
# Name: length, Length: 61, dtype: float64

# %%
# sample Method pulls out a random sample of rows or columns from a DataFrame
# DataFrame.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None)

rows = df.sample(frac =.10) #10% random sample data is generated out of the Data frame
rows
# Out:
#        company body-style  wheel-base engine-type num-of-cylinders  \
# 53      toyota      wagon        95.7         ohc             four
# 60       volvo      wagon       104.3         ohc             four
# 43      nissan      wagon        94.5         ohc             four
# 48      toyota  hatchback        95.7         ohc             four
# 26      jaguar      sedan       102.0        ohcv           twelve
# 57  volkswagen      sedan        97.3         ohc             four
#
#     horsepower  average-mileage    price
# 53          62             27.0   8778.0
# 60         114             23.0  13415.0
# 43          69             31.0   7349.0
# 48          62             35.0   5348.0
# 26         262             13.0  36000.0
# 57          52             37.0   7995.0

# %%
# nsmallest() pulls out the rows with the smallest values in a column

least_5 = df.nsmallest(5, "price")
least_5
# Out:
#        company body-style  wheel-base engine-type num-of-cylinders  \
# 13   chevrolet  hatchback        88.4           l            three
# 27       mazda  hatchback        93.1         ohc             four
# 48      toyota  hatchback        95.7         ohc             four
# 36  mitsubishi  hatchback        93.7         ohc             four
# 28       mazda  hatchback        93.1         ohc             four
#
#     horsepower  average-mileage   price
# 13          48             47.0  5151.0
# 27          68             30.0  5195.0
# 48          62             35.0  5348.0
# 36          68             37.0  5389.0
# 28          68             31.0  6095.0

# %%
# nlargest() pulls out the rows with the largest values in a column

largest_5 = df.nlargest(5, "price")
largest_5
# Out:
#           company   body-style  wheel-base engine-type num-of-cylinders  \
# 35  mercedes-benz      hardtop       112.0        ohcv            eight
# 11            bmw        sedan       103.5         ohc              six
# 34  mercedes-benz        sedan       120.9        ohcv            eight
# 46        porsche  convertible        89.5        ohcf              six
# 12            bmw        sedan       110.0         ohc              six
#
#     horsepower  average-mileage    price
# 35         184             14.0  45400.0
# 11         182             16.0  41315.0
# 34         184             14.0  40960.0
# 46         207             17.0  37028.0
# 12         182             15.0  36880.0

# %%
# shape returns a tuple representing the dimensionality of the DataFrame
# size Returns size of dataframe/series which is equivalent to total number of elements. That is rows x columns.
# ndim ‘int’ representing the number of axes / array dimensions. Returns 1 if Series, otherwise returns 2 if DataFrame
df = pd.read_csv('Automobile_data.csv')
size = df.size
shape = df.shape
dimension = df.ndim

print(f'Size: {size}, Shape: {shape}, Dimension :{dimension}')
# Out:
# Size: 549, Shape: (61, 9), Dimension :2

# %%
# DataFrame.rank(axis=0, method=’average’, numeric_only=None, na_option=’keep’, ascending=True, pct=False)

df['Rank'] = df['company'].rank()
df
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price  Rank
# 0          111             21.0  13495.0   2.0
# 1          111              NaN  16500.0   2.0
# 2          154             19.0  16500.0   2.0
# 3          102             24.0  13950.0   5.5
# 4          115             18.0  17450.0   5.5
# ..         ...              ...      ...   ...
# 56          85             27.0   7975.0  57.5
# 57          52             37.0   7995.0  57.5
# 58         100             26.0   9995.0  57.5
# 59         114             23.0  12940.0  60.5
# 60         114             23.0  13415.0  60.5
#
# [61 rows x 10 columns]

# %%
df['Rank'] = df['company'].rank(method = 'average')
df
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price  Rank
# 0          111             21.0  13495.0   2.0
# 1          111              NaN  16500.0   2.0
# 2          154             19.0  16500.0   2.0
# 3          102             24.0  13950.0   5.5
# 4          115             18.0  17450.0   5.5
# ..         ...              ...      ...   ...
# 56          85             27.0   7975.0  57.5
# 57          52             37.0   7995.0  57.5
# 58         100             26.0   9995.0  57.5
# 59         114             23.0  12940.0  60.5
# 60         114             23.0  13415.0  60.5
#
# [61 rows x 10 columns]

# %%
df['Rank'] = df['company'].rank(method = 'min')
df
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price  Rank
# 0          111             21.0  13495.0   1.0
# 1          111              NaN  16500.0   1.0
# 2          154             19.0  16500.0   1.0
# 3          102             24.0  13950.0   4.0
# 4          115             18.0  17450.0   4.0
# ..         ...              ...      ...   ...
# 56          85             27.0   7975.0  56.0
# 57          52             37.0   7995.0  56.0
# 58         100             26.0   9995.0  56.0
# 59         114             23.0  12940.0  60.0
# 60         114             23.0  13415.0  60.0
#
# [61 rows x 10 columns]

# %%
# DataFrame.query(expr, inplace=False, **kwargs)

df_price = df.query("company = 'bmw'" and 'price>40000')
df_price
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# 11            bmw      sedan       103.5   193.8         ohc              six
# 34  mercedes-benz      sedan       120.9   208.1        ohcv            eight
# 35  mercedes-benz    hardtop       112.0   199.2        ohcv            eight
#
#     horsepower  average-mileage    price  Rank
# 11         182             16.0  41315.0   8.0
# 34         184             14.0  40960.0  33.0
# 35         184             14.0  45400.0  33.0

# %%
# copy() method is used to create a copy of a Pandas object

df1 = df.copy()
df1['new'] = 'girsa'
df1
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# 11            bmw      sedan       103.5   193.8         ohc              six
# 34  mercedes-benz      sedan       120.9   208.1        ohcv            eight
# 35  mercedes-benz    hardtop       112.0   199.2        ohcv            eight
#
#     horsepower  average-mileage    price  Rank    new
# 11         182             16.0  41315.0   8.0  girsa
# 34         184             14.0  40960.0  33.0  girsa
# 35         184             14.0  45400.0  33.0  girsa

# %%
# DataFrame.duplicated(subset=None, keep='first')

result = df['horsepower'].duplicated()
result
# Out:
# 11    False
# 34    False
# 35     True
# Name: horsepower, dtype: bool

# %%
result = df['horsepower'].duplicated(keep = False)
result
# Out:
# 11    False
# 34     True
# 35     True
# Name: horsepower, dtype: bool

# %%
df = df[~result]
df
# Out:
#    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 11     bmw      sedan       103.5   193.8         ohc              six
#
#     horsepower  average-mileage    price  Rank
# 11         182             16.0  41315.0   8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 11 to 11
# Data columns (total 10 columns):
# company             1 non-null object
# body-style          1 non-null object
# wheel-base          1 non-null float64
# length              1 non-null float64
# engine-type         1 non-null object
# num-of-cylinders    1 non-null object
# horsepower          1 non-null int64
# average-mileage     1 non-null float64
# price               1 non-null float64
# Rank                1 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 88.0+ bytes

# %%
df = pd.read_csv('Automobile_data.csv')
